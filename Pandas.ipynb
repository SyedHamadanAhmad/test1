# %% [raw]
# import numpy as np

# %%
import pandas as pd

# %%
dict1= {
    "name":['harry', 'rohan', 'skillf', 'shubh'],
    "marks":[92, 34 , 56 , 88],
    "city":['rampur', 'delhi', 'noida', 'kolkata']
}

# %%
dataf=pd.DataFrame(dict1)

# %%
dataf
# Out:
#      name  marks     city
# 0   harry     92   rampur
# 1   rohan     34    delhi
# 2  skillf     56    noida
# 3   shubh     88  kolkata

# %%
dataf.to_csv('friends.csv', index=False)

# %%
dataf.head(2) #shows the starting 2 rows
# Out:
#     name  marks    city
# 0  harry     92  rampur
# 1  rohan     34   delhi

# %%
dataf.tail(2) #shows the last 2 rows
# Out:
#      name  marks     city
# 2  skillf     56    noida
# 3   shubh     88  kolkata

# %%
dataf.describe()
# Out:
#            marks
# count   4.000000
# mean   67.500000
# std    27.537853
# min    34.000000
# 25%    50.500000
# 50%    72.000000
# 75%    89.000000
# max    92.000000

# %%
sales= pd.read_csv('sales.csv')

# %%
sales
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
# code to change index ---> (filename).index=['1', '2', '3'.......]

# %%
ser=pd.Series(np.random.rand(34)) #gives series from 0 to 33

# %%
ser
# Out:
# 0     0.542500
# 1     0.843373
# 2     0.689224
# 3     0.212672
# 4     0.598844
# 5     0.236389
# 6     0.926580
# 7     0.448517
# 8     0.643457
# 9     0.839089
# 10    0.673754
# 11    0.653537
# 12    0.680978
# 13    0.889316
# 14    0.157562
# 15    0.740193
# 16    0.550382
# 17    0.931224
# 18    0.929893
# 19    0.743894
# 20    0.321760
# 21    0.274380
# 22    0.991908
# 23    0.158469
# 24    0.001823
# 25    0.762611
# 26    0.991355
# 27    0.979641
# 28    0.958568
# 29    0.742927
# 30    0.351327
# 31    0.555432
# 32    0.880948
# 33    0.887575
# dtype: float64

# %%
newdf= pd.DataFrame(np.random.rand(334, 5), index=np.arange(334)) #334 rows 5 columns

# %%
newdf.head()
# Out:
#           0         1         2         3         4
# 0  0.273736  0.688135  0.268609  0.688892  0.798115
# 1  0.476550  0.202134  0.482406  0.114971  0.152305
# 2  0.812271  0.313758  0.649693  0.625310  0.221999
# 3  0.170916  0.193901  0.420689  0.006834  0.949103
# 4  0.418692  0.871046  0.252157  0.049598  0.045548

# %%
newdf.T #Transpose
# Out:
#         0         1         2         3         4         5         6    \
# 0  0.273736  0.476550  0.812271  0.170916  0.418692  0.697281  0.251474
# 1  0.688135  0.202134  0.313758  0.193901  0.871046  0.846481  0.144626
# 2  0.268609  0.482406  0.649693  0.420689  0.252157  0.727698  0.890592
# 3  0.688892  0.114971  0.625310  0.006834  0.049598  0.412879  0.967903
# 4  0.798115  0.152305  0.221999  0.949103  0.045548  0.440625  0.354261
#
#         7         8         9    ...       324       325       326       327  \
# 0  0.464018  0.177690  0.571898  ...  0.860166  0.769081  0.324692  0.138806
# 1  0.578127  0.903776  0.882227  ...  0.913096  0.155051  0.188261  0.304879
# 2  0.843700  0.574426  0.636536  ...  0.404586  0.158322  0.037098  0.059877
# 3  0.992588  0.785767  0.994602  ...  0.060357  0.972122  0.991551  0.051922
# 4  0.288246  0.313852  0.768630  ...  0.604211  0.792605  0.438396  0.542053
#
#         328       329       330       331       332       333
# ...
